# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Projet Data Visualisation</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 20px;
#             background-color: #f9f9f9;
#             color: #333;
#         }
#         h1 {
#             text-align: center;
#             font-size: 3rem;
#             color: #2c3e50;
#             margin-bottom: 10px;
#         }
#         h2 {
#             text-align: center;
#             font-size: 2rem;
#             color: #2980b9;
#         }
#         p {
#             text-align: center;
#             font-size: 1.2rem;
#             margin: 10px auto;
#             line-height: 1.6;
#             color: black;
#         }
#         .container {
#             width: 80%;
#             margin: 50px auto;
#             padding: 20px;
#             background-color: #ffffff;
#             border: 1px solid #dcdcdc;
#             border-radius: 10px;
#             box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
#         }
#         .highlight {
#             font-weight: bold;
#             color: #e74c3c;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>Projet Data Visualisation</h1>
#         <h2>Cyril Kfouri, Mathias Robert, Maxime Maeder, Luc Renaud, Maxime Lambert</h2>
#         <p><span class="highlight">Group 2 - Data and AI</span></p>
#         <h2>Données Foncières</h2>
#         <p><strong>Objectif:</strong> Solution pour un investisseur immobilier.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <h1 style="color: #e74c3c; text-align: left; margin-bottom: 50px;">2 - Exploration Statistique des Insights</h1>
# <h2 style="text-align: center; margin-top: 20px; color: #3498db;">A - Redécouverte du DataFrame</h2>

# %%
import pandas as pd
from insights import Insights

# %%
file_path = '../CSV/données_foncières_france_2024.csv'
df = pd.read_csv(file_path, low_memory=False)

# %%
df.head()
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2024-1    2024-01-02                   1           Vente
# 1      2024-2    2024-01-03                   2           Vente
# 2      2024-3    2024-01-08                   1           Vente
# 3      2024-4    2024-01-03                   1           Vente
# 4      2024-4    2024-01-03                   1           Vente
#
#    adresse_numero adresse_nom_voie nom_commune code_departement  nombre_lots  \
# 0             NaN       LE DELIVRE      Chaley               01            0
# 1             NaN   CHEVRY DESSOUS      Chevry               01            0
# 2             NaN       PIN HAMEAU        Laiz               01            0
# 3            29.0       PL DU JURA         Gex               01            2
# 4            29.0       PL DU JURA         Gex               01            2
#
#    type_local  surface_reelle_bati  surface_terrain  \
# 0         NaN                  NaN             99.0
# ...

# %% [markdown]
# Comprendre a quel type de data frame nous allons devoiur traité (tailles, variables)

# %%
df.shape
# Out:
# (1512683, 19)

# %% [markdown]
# <h2 style="text-align: center; margin-top: 20px; color: #3498db;">B - Ajout de insights pou chaque dataframe</h2>

# %%
df['prix_m2'] = df['valeur_fonciere'] / df['surface_reelle_bati']

# %% [markdown]
# <h2 style="text-align: center; margin-top: 20px; color: #3498db;">C - Analyses Statistiques selon chaque département/Commune/Bloc</h2>

# %%
etude = Insights(df)
df_stats_par_departement, df_tendance_par_departement, df_tranches_par_departement, df_type_local_dist_par_departement,df_type_local_median_par_departement = etude.calculer_statistiques('code_departement')
df_stats_par_commune, df_tendance_par_commune, df_tranches_par_commune, df_type_local_dist_par_commune,df_type_local_median_par_commune= etude.calculer_statistiques('nom_commune')

# %%
df_stats_par_departement.head()
# Out:
#   code_departement    median           mean            std        cv  \
# 0               01  148500.0  236166.739233  573606.150566  2.428819
# 1               02   85500.0  206183.443231  439062.022701  2.129473
# 2               03   70000.0  123767.937366  282691.190806  2.284042
# 3               04   92000.0  178498.911307  430510.846775  2.411840
# 4               05  117280.0  181350.543597  343258.701484  1.892791
#
#    median_prix_m2  mean_prix_m2  nb_ventes
# 0     2487.603550   3679.600358      17659
# 1     1309.523810   1895.832055      14347
# 2     1266.244726   2283.484929      12290
# 3     2363.636364   4817.578407       5730
# 4     2806.392236   3626.220794       6097

# %%
df_tendance_par_departement.head()
# Out:
# code_departement             01             02             03             04  \
# annee_mutation
# 2024              236166.739233  206183.443231  123767.937366  178498.911307
#
# code_departement             05            06             07             08  \
# annee_mutation
# 2024              181350.543597  1.021722e+06  159156.253877  121372.049019
#
# code_departement             09             10  ...             86  \
# annee_mutation                                  ...
# 2024              114463.530606  513570.042321  ...  172661.583218
#
# code_departement             87             88             89             90  \
# annee_mutation
# 2024              207931.574353  114082.127715  156312.836228  371345.968028
#
# code_departement            91            92            93            94  \
# annee_mutation
# 2024              1.030540e+06  3.357822e+06  2.602523e+06  1.929800e+06
#
# code_departement            95
# annee_mutation
# 2024              1.878526e+06
#
# ...

# %%
df_tranches_par_departement.head()
# Out:
#   code_departement tranche_prix  count_tranche
# 0               01        <100k           7256
# 1               01    100k-200k           3603
# 2               01    200k-300k           2522
# 3               01    300k-400k           1576
# 4               01    400k-500k            773

# %%
df_type_local_dist_par_departement
# Out:
# type_local code_departement  Appartement  Dépendance  \
# 0                        01         1594        3599
# 1                        02          549        2892
# 2                        03         1046        3054
# 3                        04          824        1095
# 4                        05         1035        1239
# ..                      ...          ...         ...
# 88                       91         3264        6452
# 89                       92         7819       12007
# 90                       93         7729       10892
# 91                       94         4661        7612
# 92                       95         3434        5883
#
# type_local  Local industriel. commercial ou assimilé  Maison
# 0                                                446    2214
# 1                                                376    2707
# 2                                                292    2160
# 3                                                176     757
# ...

# %%
df_type_local_median_par_departement
# Out:
#     code_departement                                type_local  \
# 0                 01                               Appartement
# 1                 01                                Dépendance
# 2                 01  Local industriel. commercial ou assimilé
# 3                 01                                    Maison
# 4                 02                               Appartement
# ..               ...                                       ...
# 367               94                                    Maison
# 368               95                               Appartement
# 369               95                                Dépendance
# 370               95  Local industriel. commercial ou assimilé
# 371               95                                    Maison
#
#      median_prix_local
# 0           170000.000
# 1           200000.000
# 2           205000.000
# 3           257535.000
# 4            99950.000
# ..                 ...
# 367         440000.000
# ...

# %% [markdown]
# Distribution de toutes les communes en France

# %%
df_stats_par_commune.head()
# Out:
#             nom_commune    median           mean            std        cv  \
# 0                  Aast   36408.0   30084.592593   16929.375406  0.562726
# 1            Abainville   57000.0   66433.333333   16339.012618  0.245946
# 2             Abancourt   30000.0  109502.068966  100085.210888  0.914003
# 3             Abaucourt  172000.0  172000.000000   98352.137024  0.571815
# 4  Abaucourt-Hautecourt   41000.0   41000.000000       0.000000  0.000000
#
#    median_prix_m2  mean_prix_m2  nb_ventes
# 0             NaN           NaN         27
# 1     1375.806452   1375.806452          3
# 2     1802.105263   1746.079435         29
# 3      533.333333    892.140921          8
# 4             NaN           NaN         11

# %% [markdown]
# Distribution des communes d'un departement:

# %%
etude_une_commune = etude.get_insights_par_departement('75', df_stats_par_commune)
etude_une_commune
# Out:
#                     nom_commune      median          mean           std  \
# 18518  Paris 10e Arrondissement   355000.00  7.552453e+05  2.427100e+06
# 18519  Paris 11e Arrondissement   500000.00  5.568569e+06  8.925857e+06
# 18520  Paris 12e Arrondissement   385000.00  1.147099e+06  3.273615e+06
# 18521  Paris 13e Arrondissement   430000.00  3.567194e+06  8.384270e+06
# 18522  Paris 14e Arrondissement   395000.00  1.790917e+06  5.175367e+06
# 18523  Paris 15e Arrondissement   518000.00  5.690238e+06  1.368229e+07
# 18524  Paris 16e Arrondissement   757915.06  1.810355e+06  4.062857e+06
# 18525  Paris 17e Arrondissement   424200.00  1.005902e+06  3.515367e+06
# 18526  Paris 18e Arrondissement   312000.00  5.141107e+05  8.348092e+05
# 18527  Paris 19e Arrondissement   319500.00  3.971990e+05  4.622968e+05
# 18528  Paris 1er Arrondissement   643630.00  2.543184e+06  1.076936e+07
# 18529  Paris 20e Arrondissement   335000.00  7.370957e+05  2.735589e+06
# ...

# %% [markdown]
# <h2 style="margin-top: 30px;">2 - Type Local</h2>

# %%
df_maison = df[df['type_local'] == 'Maison']
df_appart = df[df['type_local'] == 'Appartement']
df_dep = df[df['type_local'] == 'Dépendance']
df_local = df[df['type_local'] == 'Local industriel. commercial ou assimilé']
counts = df['type_local'].value_counts()
counts
# Out:
# type_local
# Dépendance                                  384667
# Maison                                      229960
# Appartement                                 195153
# Local industriel. commercial ou assimilé     45924
# Name: count, dtype: int64
